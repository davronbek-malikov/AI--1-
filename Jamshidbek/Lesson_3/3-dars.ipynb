# %% [markdown]
# # Data bilan tanishuv

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install pandas
# %pip install pandas

# %%
#import 
import pandas as pd

# %%
#Datasetni yuklash
df=pd.read_csv('imdb_top_1000.csv')

# %%
print(df)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
#Datani malum bir qismini ajratib olish uchun 
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.drop(columns="Poster_Link", inplace=True)

# %%
df.head(1)
# Out:
#                Series_Title Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption          1994           A  142 min  Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
#
#          Director        Star1           Star2       Star3           Star4  \
# 0  Frank Darabont  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler
#
#    No_of_Votes       Gross
# 0      2343110  28,341,469

# %%
df.head(19)
# Out:
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# 4                                        12 Angry Men          1957
# 5       The Lord of the Rings: The Return of the King          2003
# 6                                        Pulp Fiction          1994
# 7                                    Schindler's List          1993
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 11                                       Forrest Gump          1994
# 12                    Il buono, il brutto, il cattivo          1966
# ...

# %%
#pastdan datasetni korish
df.tail(1)
# Out:
#      Series_Title Released_Year Certificate Runtime                     Genre  \
# 999  The 39 Steps          1935         NaN  86 min  Crime, Mystery, Thriller
#
#      IMDB_Rating                                           Overview  \
# 999          7.6  A man in London tries to help a counter-espion...
#
#      Meta_score          Director         Star1              Star2  \
# 999        93.0  Alfred Hitchcock  Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes Gross
# 999  Lucie Mannheim  Godfrey Tearle        51853   NaN

# %%
#Data bn tanishuv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Overview       1000 non-null   object
#  7   Meta_score     843 non-null    float64
#  8   Director       1000 non-null   object
#  9   Star1          1000 non-null   object
#  10  Star2          1000 non-null   object
#  11  Star3          1000 non-null   object
#  12  Star4          1000 non-null   object
#  13  No_of_Votes    1000 non-null   int64
#  14  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 117.3+ KB

# %%
#classification yoki regressionni aniqlash
df['Certificate'].value_counts().sum()
# Out:
# np.int64(899)

# %%
df['Certificate'].nunique()
# Out:
# 16

# %%
df[['Genre','IMDB_Rating','Gross']]
# Out:
#                         Genre  IMDB_Rating        Gross
# 0                       Drama          9.3   28,341,469
# 1                Crime, Drama          9.2  134,966,411
# 2        Action, Crime, Drama          9.0  534,858,444
# 3                Crime, Drama          9.0   57,300,000
# 4                Crime, Drama          9.0    4,360,000
# ..                        ...          ...          ...
# 995    Comedy, Drama, Romance          7.6          NaN
# 996            Drama, Western          7.6          NaN
# 997       Drama, Romance, War          7.6   30,500,000
# 998                Drama, War          7.6          NaN
# 999  Crime, Mystery, Thriller          7.6          NaN
#
# [1000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Overview       1000 non-null   object
#  7   Meta_score     843 non-null    float64
#  8   Director       1000 non-null   object
#  9   Star1          1000 non-null   object
#  10  Star2          1000 non-null   object
#  11  Star3          1000 non-null   object
#  12  Star4          1000 non-null   object
#  13  No_of_Votes    1000 non-null   int64
#  14  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 117.3+ KB

# %%
df.isnull().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.isnull().any()
# Out:
# Series_Title     False
# Released_Year    False
# Certificate       True
# Runtime          False
# Genre            False
# IMDB_Rating      False
# Overview         False
# Meta_score        True
# Director         False
# Star1            False
# Star2            False
# Star3            False
# Star4            False
# No_of_Votes      False
# Gross             True
# dtype: bool

# %% [markdown]
# # Conditions

# %%
a=-3
if a>0:
    print('ok')

# %%
#Agar son musbat bolsa ok aks olda yomon degan sozni ekranga chiqaring
a=0
if a>0:
    print('ok')
else:
    print('yomon')
# Out:
# yomon

# %%
a=10
if a>0:
    print('ok')
elif a==0:
    print('nolga teng')
elif a==10:
    print('10 soni')
else:
    print('yomon')
# Out:
# ok

# %%
'Ali'[0]
# Out:
# 'A'

# %%
#Bosh xarfi A bolgan talabalar tanlab olinsin
name='Ali'
if name[0]=='A':
    print('Selected')
else:
    print('Unselected')
# Out:
# Selected

# %%
#Bosh xarfi A  yoki S bolgan talabalar tanlab olinsin
name='Ali'
if name[0]=='A' or name[0]=='S':
    print('Selected')
else:
    print('Unselected')
# Out:
# Selected

# %% [markdown]
# # Vazifa

# %%
#Agar talabaning ismi 7 ta xarfdan iborat bolsa va uning bosh xarfi B bolsa yaxshi aks xold yomon degan yozuv chiqasin
#Agar son 2 xonali bolsa yaxshi 1 xonali bolsa yomon aks xolda out of box degan yozuv chiqsin

# %%
#  Vazifa 1:

ism = "Jamshid"

if len(ism) == 7 and ism[0] == 'B':
    print("Yaxshi")
else:
    print("Yomon")
# Out:
# Yomon

# %%
if len(ism) == 7 or name[ism] == 'B':
    print("Yaxshi")
else:
    print("Yomon")
# Out:
# Yaxshi

# %%
len(ism)
# Out:
# 7

# %%
ism[0]
# Out:
# 'J'

# %%
#Agar son 2 xonali bolsa yaxshi 1 xonali bolsa yomon aks xolda out of box degan yozuv chiqsin



son = -9

if son > 9 and son <= 99:
    print("Yaxshi")
elif son <= 9 and son >= -9:
    print("Yomon")
else:
    print('Out of Box')
# Out:
# Yomon
